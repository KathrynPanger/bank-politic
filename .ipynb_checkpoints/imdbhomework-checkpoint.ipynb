# %%
import os
import pandas as pd
import csv

# %%
imdb=pd.read_csv(r'C:\Users\kathr\OneDrive\Documents\code\ucd\ucd-sac-data-pt-03-2020-u-c\04-Pandas\2\Activities\02-Stu_GoodMovies\Unsolved\Resources\movie_scores.csv')

# %%
imdb.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
imdb_reduced=imdb[["IMDB", "IMDB_norm", "IMDB_norm_round", "IMBD_user_vote_count"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-9cc33bb21fe1> in <module>
# ----> 1 imdb_reduced=imdb[["IMDB", "IMDB_norm", "IMDB_norm_round", "IMBD_user_vote_count"]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...
